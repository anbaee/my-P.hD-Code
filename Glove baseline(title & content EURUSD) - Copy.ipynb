# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ## EURUSD NEWS

# %%
newsDF = pd.read_excel('EURUSDnews.xlsx')
newsDF = newsDF.drop('index',1)
newsDF = newsDF.drop('level_0',1)
newsDF = newsDF.drop('Unnamed: 0',1)
newsDF = newsDF.drop('key',1)
newsDF = newsDF.drop('day',1)
newsDF = newsDF.drop('month',1)
newsDF = newsDF.drop('hour',1)
print(newsDF.head())
# Out:
#                                                title  \
# 0  EUR/USD pulls back on Friday, still heads for ...
# 1  EUR/USD: Fed should help for another visit to ...
# 2  EUR/USD: Wider US-DE yield spreads and risk-of...
# 3  Forex Today: A hectic weeks kicks off with a s...
# 4      EUR/USD probing lows near 1.1720 ahead of IFO
#
#                                          articleBody               keywords  \
# 0  US dollar recovers ground as Euro gets hits by...                EURUSD,
# 1  Next week, the Federal Reserve will meet. Acco...          EURUSD,Banks,
# 2  The EUR/USD fell on Friday, tracking the 10-ye...                EURUSD,
# 3  Markets opened quietly this week, belying the ...  EURUSD,Brexit,GBPUSD,
# 4  The pair has started the week on a soft footin...                EURUSD,
#
#                                                  url               pubDate  \
# 0  https://www.fxstreet.com/news/eur-usd-pulls-ba...  2018-09-21T16:34:04Z
# 1  https://www.fxstreet.com/news/eur-usd-fed-shou...  2018-09-21T17:41:48Z
# 2  https://www.fxstreet.com/news/eur-usd-wider-us...  2018-09-24T03:44:36Z
# 3  https://www.fxstreet.com/news/forex-today-a-he...  2018-09-24T05:19:56Z
# 4  https://www.fxstreet.com/news/eur-usd-probing-...  2018-09-24T07:02:33Z
#
#                author pair summary      time  \
# 0  Mat&#237;as Salord  NaN     NaN  16:34:04
# 1  Mat&#237;as Salord  NaN     NaN  17:41:48
# 2       Omkar Godbole  NaN     NaN  03:44:36
# 3       Joshua Gibson  NaN     NaN  05:19:56
# 4       Pablo Piovano  NaN     NaN  07:02:33
#
#                                        process_title  \
# 0  ['eur', 'usd', 'pulls', 'back', 'friday', 'sti...
# 1  ['eur', 'usd', 'fed', 'help', 'another', 'visi...
# 2  ['eur', 'usd', 'wider', 'us', 'de', 'yield', '...
# 3  ['forex', 'today', 'hectic', 'weeks', 'kicks',...
# 4  ['eur', 'usd', 'probing', 'lows', 'near', 'ahe...
#
#                                         process_body  len_title  len_body  \
# 0  ['us', 'dollar', 'recovers', 'ground', 'euro',...         12       162
# 1  ['next', 'week', 'federal', 'reserve', 'meet',...          8       107
# 2  ['eur', 'usd', 'fell', 'friday', 'tracking', '...         13       154
# 3  ['markets', 'opened', 'quietly', 'week', 'bely...          7       302
# 4  ['pair', 'started', 'week', 'soft', 'footing',...          7       150
#
#         date
# 0 2018-09-21
# 1 2018-09-21
# 2 2018-09-24
# 3 2018-09-24
# 4 2018-09-24

# %%
import requests
from datetime import datetime
import numpy as np

FUTURE_PERIOD_PREDICT = 1
#newsDF =newsDF.reset_index() 
#startDate = newsDF.loc[0,'date'].timestamp()
startDate = newsDF.loc[0,'date']
startDate = startDate-np.timedelta64(FUTURE_PERIOD_PREDICT,'D')
startDate = startDate.timestamp()
startDate = int(startDate)
print(startDate)
endDate = newsDF.loc[len(newsDF)-1,'date']+np.timedelta64( FUTURE_PERIOD_PREDICT,'D')
endDate = int(endDate.timestamp())
print(endDate)

queryString = 'https://finnhub.io/api/v1/forex/candle?symbol=OANDA:EUR_USD&resolution=D&from='
queryString += str(startDate ) + '&to=' + str(endDate)+ '&token='

columns={'Close','High','Low','Open','Status','timestamp','Volume'}
r = requests.get(queryString)

marketDF = pd.DataFrame(r.json())

marketDF['Close'] = marketDF['c']
marketDF = marketDF.drop('c',1)

marketDF['Open'] = marketDF['o']
marketDF = marketDF.drop('o',1)

marketDF['Low'] = marketDF['l']
marketDF = marketDF.drop('l',1)

marketDF['High'] = marketDF['h']
marketDF = marketDF.drop('h',1)

marketDF = marketDF.drop('s',1)


marketDF['timestamp'] = marketDF['t']
marketDF = marketDF.drop('t',1)

marketDF['Volume'] = marketDF['v']
marketDF = marketDF.drop('v',1)

marketDF['Date'] = [datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d') for ts in marketDF['timestamp']]

marketDF = marketDF.drop('timestamp',1)
# Out:
# 1537401600
# 1605225600

# %%
print(marketDF.head())
print(marketDF.describe())
# Out:
#      Close     Open      Low     High  Volume        Date
# 0  1.17765  1.16722  1.16678  1.17842  159764  2018-09-19
# 1  1.17452  1.17765  1.17320  1.18024  152617  2018-09-20
# 2  1.17451  1.17421  1.17233  1.18147  125476  2018-09-23
# 3  1.17647  1.17476  1.17302  1.17919  137517  2018-09-24
# 4  1.17385  1.17641  1.17250  1.17975  160972  2018-09-25
#             Close        Open         Low        High         Volume
# count  559.000000  559.000000  559.000000  559.000000     559.000000
# mean     1.127417    1.127348    1.124109    1.131253   98078.576029
# std      0.028060    0.027971    0.027806    0.028217   54294.828908
# min      1.069010    1.068940    1.063470    1.081120       1.000000
# 25%      1.107735    1.107770    1.105720    1.110605   57937.000000
# 50%      1.123840    1.123510    1.120920    1.127440   81235.000000
# 75%      1.139935    1.139795    1.136035    1.144150  126532.000000
# max      1.193500    1.193070    1.190060    1.201050  304150.000000

# %%
def classify(current, future):
    if float(future) > float(current):  # if the future price is higher than the current, that's a buy, or a 1
        return 1
    else:  # otherwise... it's a 0!
        return 0

marketDF.fillna(method="ffill", inplace=True)  # if there are gaps in data, use previously known values
marketDF.dropna(inplace=True)

marketDF['future'] = marketDF['Close'].shift(-FUTURE_PERIOD_PREDICT)
marketDF['target'] = list(map(classify, marketDF['Close'], marketDF['future']))
marketDF = marketDF.drop('future',1)

# %%
print(marketDF.head())
print(marketDF.describe())
# Out:
#      Close     Open      Low     High  Volume        Date  target
# 0  1.17765  1.16722  1.16678  1.17842  159764  2018-09-19       0
# 1  1.17452  1.17765  1.17320  1.18024  152617  2018-09-20       0
# 2  1.17451  1.17421  1.17233  1.18147  125476  2018-09-23       1
# 3  1.17647  1.17476  1.17302  1.17919  137517  2018-09-24       0
# 4  1.17385  1.17641  1.17250  1.17975  160972  2018-09-25       0
#             Close        Open         Low        High         Volume  \
# count  559.000000  559.000000  559.000000  559.000000     559.000000
# mean     1.127417    1.127348    1.124109    1.131253   98078.576029
# std      0.028060    0.027971    0.027806    0.028217   54294.828908
# min      1.069010    1.068940    1.063470    1.081120       1.000000
# 25%      1.107735    1.107770    1.105720    1.110605   57937.000000
# 50%      1.123840    1.123510    1.120920    1.127440   81235.000000
# 75%      1.139935    1.139795    1.136035    1.144150  126532.000000
# max      1.193500    1.193070    1.190060    1.201050  304150.000000
#
#            target
# count  559.000000
# mean     0.495528
# std      0.500428
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
import matplotlib.pyplot as plt   # plotting
import seaborn as sns   # plotting heatmap
import statsmodels.api as sm  # seasonal trend decomposition
from statsmodels.graphics import tsaplots   # autocorrelation
# %matplotlib inline
marketDF.plot(subplots=True,
        layout=(6, 3),
        figsize=(22,22),
        fontsize=10, 
        linewidth=2,
        sharex=False,
        title='Visualization of the original Time Series')
plt.show()

# %% [markdown]
# ## assign label up/down to news

# %%
newsDF['date']= [pd.to_datetime(w) for w in newsDF['date']]
print(type(newsDF['date'][0]))
marketDF['Date']= [pd.to_datetime(w) for w in marketDF['Date']]
print(type(newsDF['date'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
def assign_dayLabel(date,marketInfo):
    i=0
    while marketInfo['Date'][i] < date:
        i = i+1
    if (marketInfo['Date'][i] == date):
        return(marketInfo['target'][i])
    else:
        return(marketInfo['target'][i-1])

 
newsDF['target'] = [assign_dayLabel(w,marketDF) for w in newsDF['date']]

# %% [markdown]
# ## train and test split

# %%
newsDF = newsDF.set_index('date')
dates = sorted(newsDF.index.values)  # get the dates
last_5pct = sorted(newsDF.index.values)[-int(0.2*len(dates))]  # get the last 20% of the times

test_main_df = newsDF[(newsDF.index >= last_5pct)]  # make the validation data where the index is in the last 5%
main_df = newsDF[(newsDF.index < last_5pct)]  # now the main_df is all the data up to the last 5%

dates = sorted(main_df.index.values)  # get the dates
last_5pct = sorted(main_df.index.values)[-int(0.25*len(dates))]  # get the last 20% of the times
validation_main_df =  main_df[(main_df.index > last_5pct)]  
main_df = main_df[(main_df.index < last_5pct)] 

print(main_df.shape)
print(validation_main_df.shape)
print(test_main_df.shape)

print(main_df.head())
print(main_df.describe())
# Out:
# (3555, 14)
# (1170, 14)
# (1190, 14)
#                                                         title  \
# date
# 2018-09-21  EUR/USD pulls back on Friday, still heads for ...
# 2018-09-21  EUR/USD: Fed should help for another visit to ...
# 2018-09-24  EUR/USD: Wider US-DE yield spreads and risk-of...
# 2018-09-24  Forex Today: A hectic weeks kicks off with a s...
# 2018-09-24      EUR/USD probing lows near 1.1720 ahead of IFO
#
#                                                   articleBody  \
# date
# 2018-09-21  US dollar recovers ground as Euro gets hits by...
# 2018-09-21  Next week, the Federal Reserve will meet. Acco...
# 2018-09-24  The EUR/USD fell on Friday, tracking the 10-ye...
# 2018-09-24  Markets opened quietly this week, belying the ...
# 2018-09-24  The pair has started the week on a soft footin...
#
#                          keywords  \
# date
# 2018-09-21                EURUSD,
# 2018-09-21          EURUSD,Banks,
# 2018-09-24                EURUSD,
# 2018-09-24  EURUSD,Brexit,GBPUSD,
# 2018-09-24                EURUSD,
#
#                                                           url  \
# date
# 2018-09-21  https://www.fxstreet.com/news/eur-usd-pulls-ba...
# 2018-09-21  https://www.fxstreet.com/news/eur-usd-fed-shou...
# 2018-09-24  https://www.fxstreet.com/news/eur-usd-wider-us...
# 2018-09-24  https://www.fxstreet.com/news/forex-today-a-he...
# 2018-09-24  https://www.fxstreet.com/news/eur-usd-probing-...
#
#                          pubDate              author pair summary      time  \
# date
# 2018-09-21  2018-09-21T16:34:04Z  Mat&#237;as Salord  NaN     NaN  16:34:04
# 2018-09-21  2018-09-21T17:41:48Z  Mat&#237;as Salord  NaN     NaN  17:41:48
# 2018-09-24  2018-09-24T03:44:36Z       Omkar Godbole  NaN     NaN  03:44:36
# 2018-09-24  2018-09-24T05:19:56Z       Joshua Gibson  NaN     NaN  05:19:56
# 2018-09-24  2018-09-24T07:02:33Z       Pablo Piovano  NaN     NaN  07:02:33
#
#                                                 process_title  \
# date
# 2018-09-21  ['eur', 'usd', 'pulls', 'back', 'friday', 'sti...
# 2018-09-21  ['eur', 'usd', 'fed', 'help', 'another', 'visi...
# 2018-09-24  ['eur', 'usd', 'wider', 'us', 'de', 'yield', '...
# 2018-09-24  ['forex', 'today', 'hectic', 'weeks', 'kicks',...
# 2018-09-24  ['eur', 'usd', 'probing', 'lows', 'near', 'ahe...
#
#                                                  process_body  len_title  \
# date
# 2018-09-21  ['us', 'dollar', 'recovers', 'ground', 'euro',...         12
# 2018-09-21  ['next', 'week', 'federal', 'reserve', 'meet',...          8
# 2018-09-24  ['eur', 'usd', 'fell', 'friday', 'tracking', '...         13
# 2018-09-24  ['markets', 'opened', 'quietly', 'week', 'bely...          7
# 2018-09-24  ['pair', 'started', 'week', 'soft', 'footing',...          7
#
#             len_body  target
# date
# 2018-09-21       162       0
# 2018-09-21       107       0
# 2018-09-24       154       0
# 2018-09-24       302       0
# 2018-09-24       150       0
#          len_title     len_body       target
# count  3555.000000  3555.000000  3555.000000
# mean      8.213221   145.600281     0.479325
# std       2.547157    74.478085     0.499643
# min       1.000000     0.000000     0.000000
# 25%       6.000000    91.000000     0.000000
# 50%       8.000000   136.000000     0.000000
# 75%      10.000000   196.000000     1.000000
# max      26.000000   909.000000     1.000000

# %%
def preprocess_df(df):
    phrase = []
    targets = []
    for i,row in df.iterrows():
        phrase.append(row['process_title']+','+str(row['process_body']))
        targets.append(row['target'])
    X = np.asarray(phrase)
    Y = np.asarray(targets, dtype=int)

    return X, Y

# %%
train_x, train_y = preprocess_df(main_df)
validation_x, validation_y = preprocess_df(validation_main_df)
test_x, test_y = preprocess_df(test_main_df)

# %%
print(type(test_x[0]))
print(test_x[0])
# Out:
# <class 'numpy.str_'>
# ['non', 'farm', 'payrolls', 'august', 'preview', 'us', 'dollar', 'waiting', 'good', 'news'],['payroll', 'expected', 'dip', 'million', 'million', 'july', 'unemployment', 'rate', 'drop', 'dollar', 'boosted', 'better', 'forecast', 'august', 'manufacturing', 'ism', 'long', 'awaited', 'us', 'economic', 'slowdown', 'second', 'covid', 'wave', 'never', 'arrived', 'absence', 'dire', 'statistics', 'enough', 'lift', 'dollar', 'five', 'week', 'slough', 'good', 'news', 'required', 'best', 'would', 'surging', 'job', 'market', 'non', 'farm', 'payrolls', 'forecast', 'rise', 'million', 'august', 'million', 'july', 'smallest', 'gain', 'since', 'recovery', 'began', 'may', 'nfp', 'fxstreet', 'unemployment', 'rate', 'predicted', 'fall', 'lowest', 'since', 'pandemic', 'shutdowns', 'peaked', 'april', 'july', 'underemployment', 'rate', 'projected', 'rise', 'august', 'july', 'would', 'first', 'increase', 'since', 'april', 'average', 'hourly', 'earnings', 'estimated', 'flat', 'august', 'july', 'rsquo', 'gain', 'annual', 'wages', 'fall', 'adp', 'payrolls', 'private', 'payrolls', 'automatic', 'data', 'processing', 'issued', 'wednesday', 'employment', 'situation', 'report', 'generally', 'considered', 'best', 'indicator', 'national', 'list', 'labor', 'department', 'assembled', 'companies', 'whose', 'payrolls', 'processed', 'adp', 'represent', 'smaller', 'version', 'non', 'governmental', 'jobs', 'tracked', 'labor', 'firms', 'projected', 'add', 'new', 'employees', 'august', 'far', 'reported', 'july', 'despite', 'relatively', 'close', 'historical', 'association', 'non', 'farm', 'payrolls', 'estimates', 'adp', 'employment', 'change', 'figures', 'reuters', 'survey', 'economists', 'uncharacteristically', 'wayward', 'past', 'three', 'months', 'correlation', 'non', 'farm', 'payrolls', 'numbers', 'weak', 'revisions', 'adp', 'uncommonly', 'large', 'july', 'estimate', 'adp', 'rsquo', 'payrolls', 'million', 'actual', 'figures', 'nfp', 'figure', 'million', 'million', 'forecast', 'june', 'adp', 'forecast', 'million', 'first', 'release', 'million', 'revision', 'million', 'nfp', 'estimate', 'million', 'million', 'revision', 'may', 'similar', 'problems', 'consensus', 'adp', 'estimate', 'million', 'initial', 'release', 'million', 'adjustment', 'one', 'month', 'later', 'million', 'swing', 'million', 'nfp', 'forecast', 'million', 'reality', 'million', 'revised', 'million', 'labor', 'market', 'particularly', 'hard', 'gauge', 'enormous', 'layoffs', 'march', 'april', 'may', 'rsquo', 'surprise', 'resumption', 'hiring', 'foreseen', 'analysts', 'nonetheless', 'faltering', 'accuracy', 'adp', 'forecast', 'late', 'declining', 'correlation', 'nfp', 'relative', 'importance', 'statistic', 'possible', 'market', 'impact', 'diminished', 'manufacturing', 'pmi', 'evidence', 'difficulty', 'analysts', 'estimating', 'strength', 'recovery', 'comes', 'purchasing', 'managers', 'rsquo', 'indexes', 'manufacturing', 'pmi', 'rsquo', 'performedestimates', 'three', 'months', 'running', 'june', 'forecast', 'result', 'july', 'august', 'prediction', 'reality', 'manufacturing', 'pmi', 'fxstreet', 'discrepancy', 'even', 'greater', 'new', 'orders', 'index', 'june', 'estimate', 'result', 'july', 'august', 'gap', 'employment', 'lagged', 'two', 'last', 'three', 'months', 'remains', 'contraction', 'june', 'estimate', 'result', 'july', 'estimate', 'august', 'estimate', 'result', 'initial', 'jobless', 'claims', 'jobless', 'claims', 'third', 'indicator', 'standard', 'correlation', 'faltered', 'assume', 'nfp', 'rise', 'expected', 'august', 'would', 'four', 'months', 'payroll', 'gains', 'accompanied', 'average', 'initial', 'claims', 'well', 'million', 'week', 'would', 'near', 'impossibility', 'prior', 'economy', 'claims', 'expected', 'drop', 'august', 'week', 'million', 'previously', 'would', 'second', 'week', 'million', 'last', 'six', 'months', 'continuing', 'claims', 'estimated', 'fall', 'million', 'august', 'prior', 'week', 'conclusion', 'dollar', 'predictive', 'correlations', 'adp', 'payrolls', 'pmi', 'employment', ...

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">   تبدیل Labelها به بردار One-Hot
# </div>

# %%
def read_glove_vecs(glove_file):
    with open(glove_file, encoding="utf8") as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map , words

# %%
word_to_index, index_to_word, word_to_vec_map , words = read_glove_vecs('D:/phd thesis/dataSet/glove.6B/glove.6B.50d.txt')
embedding_dim = 50

# %% [markdown]
# You've loaded:
# - `word_to_index`: dictionary mapping from words to their indices in the vocabulary (400,001 words, with the valid indices ranging from 0 to 400,000)
# - `index_to_word`: dictionary mapping from indices to their corresponding words in the vocabulary
# - `word_to_vec_map`: dictionary mapping words to their GloVe vector

# %%
import numpy as np
np.random.seed(0)
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Dropout, LSTM, Activation,Embedding, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.initializers import glorot_uniform
np.random.seed(1)

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">   تبدیل جمله به indexها
# </div>
# <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">
# این تابع طول تمام جمله ها را نیز یکسان میکند.
# </div>

# %%
import re

def sentences_to_indices(X, word_to_index, max_len):
    m = X.shape[0]                                   # number of training examples
    
    # Initialize X_indices as a numpy matrix of zeros and the correct shape (≈ 1 line)
    X_indices = np.zeros((m, max_len))
    embedding_dim
    for i in range(m):                               # loop over training examples
        
        # Convert the ith training sentence in lower case and split is into words. You should get a list of words.
        
        
        sentence_words =  [w.rstrip('\']').lstrip('[\'') for w in X[i].split(',')]
        sentence_words = sentence_words[:max_len]

        # Loop over the words of sentence_words
        for j, w in enumerate(sentence_words):
            # Set the (i,j)th entry of X_indices to the index of the correct word.
            if w in words:

                word = w.lstrip('[\'')
                word = word.rstrip('\']')
                if len(str(word))>0:
                    X_indices[i, j] = word_to_index[word]
            else:
                 X_indices[i, j] = word_to_index['unk']

    return X_indices

# %% [markdown]
# Run the following cell to check what `sentences_to_indices()` does, and check your results.

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">   تابعی برای ایجاد لایه Embedding و لود وزن های از پیش آموزش داده شده
# </div>

# %%
def pretrained_embedding_layer(word_to_vec_map, word_to_index):
    
    vocab_len = len(word_to_index) + 1                  # adding 1 to fit Keras embedding (requirement)
    emb_dim = embedding_dim      # define dimensionality of your GloVe word vectors (= 50)
    
    # Initialize the embedding matrix as a numpy array of zeros of shape (vocab_len, dimensions of word vectors = emb_dim)
    emb_matrix = np.zeros((vocab_len, emb_dim))
    
    # Set each row "index" of the embedding matrix to be the word vector representation of the "index"th word of the vocabulary
    for word, index in word_to_index.items():
        emb_matrix[index, :] = word_to_vec_map[word]

    # Define Keras embedding layer with the correct output/input sizes, make it trainable. Use Embedding(...). Make sure to set trainable=False. 
    embedding_layer = Embedding(vocab_len, emb_dim, trainable = False)

    # Build the embedding layer, it is required before setting the weights of the embedding layer. Do not modify the "None".
    embedding_layer.build((None,))
    
    # Set the weights of the embedding layer to the embedding matrix. Your layer is now pretrained.
    embedding_layer.set_weights([emb_matrix])
    
    return embedding_layer

# %% [markdown]
# ## 2.3 Building the model

# %%
maxLen = 200
def classifier_V2(input_shape, word_to_vec_map, word_to_index):

    # Define sentence_indices as the input of the graph, it should be of shape input_shape and dtype 'int32' (as it contains indices).
    sentence_indices = Input(input_shape, dtype = np.int32)
    
    # Create the embedding layer pretrained with GloVe Vectors (≈1 line)
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)
    
    # Propagate sentence_indices through your embedding layer, you get back the embeddings
    embeddings = embedding_layer(sentence_indices)
    
    # Propagate the embeddings through an LSTM layer with 128-dimensional hidden state
    # Be careful, the returned output should be a batch of sequences.
    X = LSTM(128, return_sequences=True)(embeddings)
    # Add dropout with a probability of 0.5
    X = Dropout(0.5)(X)
    # Propagate X trough another LSTM layer with 128-dimensional hidden state
    X = LSTM(128)(X)
    # Add dropout with a probability of 0.5
    X = Dropout(0.5)(X)
    # Be careful, the returned output should be a single hidden state, not a batch of sequences.
    # Propagate X through a Dense layer with softmax activation to get back a batch of 5-dimensional vectors.
    X = Dense(2, activation = 'softmax')(X)
    
    # Create Model instance which converts sentence_indices into X.
    model = Model(sentence_indices, X)
    
    
    return model

# %%
model = classifier_V2((maxLen,), word_to_vec_map, word_to_index)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 200)]             0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 200, 50)           20000050
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 200, 128)          91648
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 128)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 20,223,540
# Trainable params: 223,490
# Non-trainable params: 20,000,050
# _________________________________________________________________

# %% [markdown]
# As usual, after creating your model in Keras, you need to compile it and define what loss, optimizer and metrics your are want to use. Compile your model using `categorical_crossentropy` loss, `adam` optimizer and `['accuracy']` metrics:

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# It's time to train your model. Your Emojifier-V2 `model` takes as input an array of shape (`m`, `max_len`) and outputs probability vectors of shape (`m`, `number of classes`). We thus have to convert X_train (array of sentences as strings) to X_train_indices (array of sentences as list of word indices), and Y_train (labels as indices) to Y_train_oh (labels as one-hot vectors).

# %%
Y_oh_train =  keras.utils.to_categorical(train_y,  2)
Y_oh_validation =  keras.utils.to_categorical(validation_y,  2)
Y_oh_test =  keras.utils.to_categorical(test_y, 2)

# %%
X_train_indices = sentences_to_indices(train_x, word_to_index, maxLen)
X_validation_indices = sentences_to_indices(validation_x, word_to_index, maxLen)

# %%
print(X_validation_indices.shape)
history = model.fit(X_train_indices, Y_oh_train,
          epochs = 60, batch_size = 32, 
          shuffle=True ,
          validation_data=(X_validation_indices,Y_oh_validation)
         )
# Out:
# (1170, 200)
# Train on 3555 samples, validate on 1170 samples
# Epoch 1/60
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002B3828CDAF8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002B3828CDAF8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# 3555/3555 [==============================] - 98s 28ms/sample - loss: 0.6997 - accuracy: 0.5111 - val_loss: 0.6956 - val_accuracy: 0.4632
# Epoch 2/60
# 3555/3555 [==============================] - 99s 28ms/sample - loss: 0.6956 - accuracy: 0.5165 - val_loss: 0.7163 - val_accuracy: 0.3829
# Epoch 3/60
# 3555/3555 [==============================] - 101s 28ms/sample - loss: 0.6954 - accuracy: 0.5173 - val_loss: 0.7034 - val_accuracy: 0.3855
# Epoch 4/60
# 3555/3555 [==============================] - 101s 28ms/sample - loss: 0.6944 - accuracy: 0.5170 - val_loss: 0.6976 - val_accuracy: 0.4632
# Epoch 5/60
# 3555/3555 [==============================] - 97s 27ms/sample - loss: 0.6933 - accuracy: 0.5243 - val_loss: 0.6936 - val_accuracy: 0.4632
# Epoch 6/60
# 3555/3555 [==============================] - 98s 27ms/sample - loss: 0.6943 - accuracy: 0.5114 - val_loss: 0.7032 - val_accuracy: 0.3949
# Epoch 7/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6931 - accuracy: 0.5176 - val_loss: 0.6996 - val_accuracy: 0.3897
# Epoch 8/60
# 3555/3555 [==============================] - 101s 28ms/sample - loss: 0.6928 - accuracy: 0.5260 - val_loss: 0.7017 - val_accuracy: 0.3966
# Epoch 9/60
# 3555/3555 [==============================] - 100s 28ms/sample - loss: 0.6927 - accuracy: 0.5280 - val_loss: 0.7005 - val_accuracy: 0.4632
# Epoch 10/60
# 3555/3555 [==============================] - 95s 27ms/sample - loss: 0.6930 - accuracy: 0.5131 - val_loss: 0.6971 - val_accuracy: 0.3906
# Epoch 11/60
# 3555/3555 [==============================] - 89s 25ms/sample - loss: 0.6932 - accuracy: 0.5150 - val_loss: 0.7022 - val_accuracy: 0.3932
# Epoch 12/60
# 3555/3555 [==============================] - 94s 26ms/sample - loss: 0.6927 - accuracy: 0.5195 - val_loss: 0.6977 - val_accuracy: 0.3897
# Epoch 13/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6926 - accuracy: 0.5249 - val_loss: 0.7109 - val_accuracy: 0.3829
# Epoch 14/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6926 - accuracy: 0.5252 - val_loss: 0.7185 - val_accuracy: 0.3880
# Epoch 15/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.7114 - val_accuracy: 0.3932
# Epoch 16/60
# 3555/3555 [==============================] - 89s 25ms/sample - loss: 0.6929 - accuracy: 0.5232 - val_loss: 0.7025 - val_accuracy: 0.3897
# Epoch 17/60
# 3555/3555 [==============================] - 88s 25ms/sample - loss: 0.6921 - accuracy: 0.5291 - val_loss: 0.7051 - val_accuracy: 0.3897
# Epoch 18/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6917 - accuracy: 0.5204 - val_loss: 0.7104 - val_accuracy: 0.3932
# Epoch 19/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6930 - accuracy: 0.5212 - val_loss: 0.7030 - val_accuracy: 0.3932
# Epoch 20/60
# 3555/3555 [==============================] - 88s 25ms/sample - loss: 0.6920 - accuracy: 0.5170 - val_loss: 0.7166 - val_accuracy: 0.3906
# Epoch 21/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6920 - accuracy: 0.5241 - val_loss: 0.7061 - val_accuracy: 0.3897
# Epoch 22/60
# 3555/3555 [==============================] - 89s 25ms/sample - loss: 0.6918 - accuracy: 0.5235 - val_loss: 0.6978 - val_accuracy: 0.3915
# Epoch 23/60
# 3555/3555 [==============================] - 89s 25ms/sample - loss: 0.6926 - accuracy: 0.5241 - val_loss: 0.7055 - val_accuracy: 0.4632
# Epoch 24/60
# 3555/3555 [==============================] - 87s 24ms/sample - loss: 0.6922 - accuracy: 0.5345 - val_loss: 0.6966 - val_accuracy: 0.4615
# Epoch 25/60
# 3555/3555 [==============================] - 83s 23ms/sample - loss: 0.6924 - accuracy: 0.5212 - val_loss: 0.7034 - val_accuracy: 0.3889
# Epoch 26/60
# 3555/3555 [==============================] - 83s 23ms/sample - loss: 0.6925 - accuracy: 0.5195 - val_loss: 0.7066 - val_accuracy: 0.3949
# Epoch 27/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6924 - accuracy: 0.5195 - val_loss: 0.7014 - val_accuracy: 0.3966
# Epoch 28/60
# 3555/3555 [==============================] - 88s 25ms/sample - loss: 0.6919 - accuracy: 0.5201 - val_loss: 0.7003 - val_accuracy: 0.3949
# Epoch 29/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6924 - accuracy: 0.5238 - val_loss: 0.7005 - val_accuracy: 0.3897
# Epoch 30/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6924 - accuracy: 0.5150 - val_loss: 0.7063 - val_accuracy: 0.3923
# Epoch 31/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6917 - accuracy: 0.5229 - val_loss: 0.7056 - val_accuracy: 0.3872
# Epoch 32/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6923 - accuracy: 0.5252 - val_loss: 0.7041 - val_accuracy: 0.3880
# Epoch 33/60
# 3555/3555 [==============================] - 88s 25ms/sample - loss: 0.6910 - accuracy: 0.5241 - val_loss: 0.7062 - val_accuracy: 0.3915
# Epoch 34/60
# 3555/3555 [==============================] - 87s 24ms/sample - loss: 0.6919 - accuracy: 0.5249 - val_loss: 0.6980 - val_accuracy: 0.3940
# Epoch 35/60
# 3555/3555 [==============================] - 84s 24ms/sample - loss: 0.6922 - accuracy: 0.5263 - val_loss: 0.6985 - val_accuracy: 0.3897
# Epoch 36/60
# 3555/3555 [==============================] - 86s 24ms/sample - loss: 0.6919 - accuracy: 0.5207 - val_loss: 0.7053 - val_accuracy: 0.3880
# Epoch 37/60
# 3555/3555 [==============================] - 90s 25ms/sample - loss: 0.6918 - accuracy: 0.5238 - val_loss: 0.7015 - val_accuracy: 0.3906
# Epoch 38/60
# 3555/3555 [==============================] - 82s 23ms/sample - loss: 0.6919 - accuracy: 0.5204 - val_loss: 0.7066 - val_accuracy: 0.3889
# Epoch 39/60
# 3555/3555 [==============================] - 82s 23ms/sample - loss: 0.6913 - accuracy: 0.5260 - val_loss: 0.6995 - val_accuracy: 0.4581
# Epoch 40/60
# 3555/3555 [==============================] - 86s 24ms/sample - loss: 0.6923 - accuracy: 0.5255 - val_loss: 0.6995 - val_accuracy: 0.3923
# Epoch 41/60
# 3555/3555 [==============================] - 83s 23ms/sample - loss: 0.6915 - accuracy: 0.5226 - val_loss: 0.7070 - val_accuracy: 0.3897
# Epoch 42/60
# 3555/3555 [==============================] - 104s 29ms/sample - loss: 0.6914 - accuracy: 0.5241 - val_loss: 0.7046 - val_accuracy: 0.3906
# Epoch 43/60
# 3555/3555 [==============================] - 117s 33ms/sample - loss: 0.6914 - accuracy: 0.5249 - val_loss: 0.7014 - val_accuracy: 0.3915
# Epoch 44/60
# 3555/3555 [==============================] - 121s 34ms/sample - loss: 0.6916 - accuracy: 0.5257 - val_loss: 0.7080 - val_accuracy: 0.3915
# Epoch 45/60
# 3555/3555 [==============================] - 112s 32ms/sample - loss: 0.6914 - accuracy: 0.5297 - val_loss: 0.7033 - val_accuracy: 0.3897
# Epoch 46/60
# 3555/3555 [==============================] - 99s 28ms/sample - loss: 0.6910 - accuracy: 0.5249 - val_loss: 0.7052 - val_accuracy: 0.3897
# Epoch 47/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6910 - accuracy: 0.5271 - val_loss: 0.7027 - val_accuracy: 0.3932
# Epoch 48/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6915 - accuracy: 0.5260 - val_loss: 0.7018 - val_accuracy: 0.3897
# Epoch 49/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6913 - accuracy: 0.5280 - val_loss: 0.7022 - val_accuracy: 0.3915
# Epoch 50/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6913 - accuracy: 0.5210 - val_loss: 0.7031 - val_accuracy: 0.3880
# Epoch 51/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6915 - accuracy: 0.5243 - val_loss: 0.7111 - val_accuracy: 0.3880
# Epoch 52/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6910 - accuracy: 0.5305 - val_loss: 0.7050 - val_accuracy: 0.3880
# Epoch 53/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6908 - accuracy: 0.5260 - val_loss: 0.7044 - val_accuracy: 0.3915
# Epoch 54/60
# 3555/3555 [==============================] - 91s 26ms/sample - loss: 0.6913 - accuracy: 0.5241 - val_loss: 0.7009 - val_accuracy: 0.3923
# Epoch 55/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6903 - accuracy: 0.5271 - val_loss: 0.7051 - val_accuracy: 0.3915
# Epoch 56/60
# 3555/3555 [==============================] - 97s 27ms/sample - loss: 0.6913 - accuracy: 0.5263 - val_loss: 0.7015 - val_accuracy: 0.3932
# Epoch 57/60
# 3555/3555 [==============================] - 94s 26ms/sample - loss: 0.6913 - accuracy: 0.5271 - val_loss: 0.7034 - val_accuracy: 0.3880
# Epoch 58/60
# 3555/3555 [==============================] - 92s 26ms/sample - loss: 0.6909 - accuracy: 0.5266 - val_loss: 0.7017 - val_accuracy: 0.3923
# Epoch 59/60
# 3555/3555 [==============================] - 99s 28ms/sample - loss: 0.6906 - accuracy: 0.5246 - val_loss: 0.7056 - val_accuracy: 0.3923
# Epoch 60/60
# 3555/3555 [==============================] - 93s 26ms/sample - loss: 0.6910 - accuracy: 0.5280 - val_loss: 0.7060 - val_accuracy: 0.3915

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  #plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)


plot_loss(history)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
X_test_indices = sentences_to_indices(test_x, word_to_index, max_len = maxLen)
Y_test_oh = keras.utils.to_categorical(test_y, 2)
loss, acc = model.evaluate(X_test_indices, Y_test_oh)
print()
print("Test accuracy = ", acc)
# Out:
# 1190/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Test accuracy =  0.51932776

# %%
maxLen = 200
def Emojify_V1(input_shape, word_to_vec_map, word_to_index):

    # Define sentence_indices as the input of the graph, it should be of shape input_shape and dtype 'int32' (as it contains indices).
    sentence_indices = Input(input_shape, dtype = np.int32)
    
    # Create the embedding layer pretrained with GloVe Vectors (≈1 line)
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)
    
    # Propagate sentence_indices through your embedding layer, you get back the embeddings
    
    embeddings = embedding_layer(sentence_indices)
    x = Conv1D(filters=64, kernel_size=3, activation='relu',padding='same', input_shape = input_shape)(embeddings)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)
    x = Conv1D(filters=64, kernel_size=3, activation='relu',padding='same',input_shape = input_shape)(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    x = Dense(input_shape[0]/10, activation='relu')(x)
    preds = Dense(2, activation='softmax')(x)

    model = Model(sentence_indices, preds)
    return model

# %%
model = Emojify_V1((maxLen,), word_to_vec_map, word_to_index)
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 200)]             0
# _________________________________________________________________
# embedding_15 (Embedding)     (None, 200, 50)           20000050
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 200, 64)           9664
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 100, 64)           0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 100, 64)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                128020
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 20,137,776
# Trainable params: 137,726
# Non-trainable params: 20,000,050
# _________________________________________________________________

# %%
history_conv1d = model.fit(X_train_indices, Y_oh_train,
          epochs = 60, batch_size = 32, 
          shuffle=True ,
          validation_data=(X_validation_indices,Y_oh_validation)
         )
# Out:
# Train on 3555 samples, validate on 1170 samples
# Epoch 1/60
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002B3A245FA68> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002B3A245FA68> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.6963 - accuracy: 0.5159 - val_loss: 0.7001 - val_accuracy: 0.3829
# Epoch 2/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.6930 - accuracy: 0.5201 - val_loss: 0.6885 - val_accuracy: 0.5590
# Epoch 3/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.6879 - accuracy: 0.5364 - val_loss: 0.6965 - val_accuracy: 0.5000
# Epoch 4/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.6809 - accuracy: 0.5567 - val_loss: 0.7825 - val_accuracy: 0.3667
# Epoch 5/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.6743 - accuracy: 0.5648 - val_loss: 0.7173 - val_accuracy: 0.4641
# Epoch 6/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.6663 - accuracy: 0.5837 - val_loss: 0.7310 - val_accuracy: 0.4513
# Epoch 7/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.6573 - accuracy: 0.5947 - val_loss: 0.7430 - val_accuracy: 0.5043
# Epoch 8/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.6488 - accuracy: 0.6070 - val_loss: 0.8030 - val_accuracy: 0.4120
# Epoch 9/60
# 3555/3555 [==============================] - 12s 3ms/sample - loss: 0.6367 - accuracy: 0.6236 - val_loss: 0.8445 - val_accuracy: 0.4179
# Epoch 10/60
# 3555/3555 [==============================] - 12s 3ms/sample - loss: 0.6263 - accuracy: 0.6323 - val_loss: 0.8205 - val_accuracy: 0.4128
# Epoch 11/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.6073 - accuracy: 0.6571 - val_loss: 0.8628 - val_accuracy: 0.4393
# Epoch 12/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.5985 - accuracy: 0.6568 - val_loss: 0.8670 - val_accuracy: 0.4538
# Epoch 13/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.5826 - accuracy: 0.6723 - val_loss: 0.9320 - val_accuracy: 0.4265
# Epoch 14/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.5612 - accuracy: 0.6945 - val_loss: 0.9581 - val_accuracy: 0.4427
# Epoch 15/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.5556 - accuracy: 0.6833 - val_loss: 0.9853 - val_accuracy: 0.4564
# Epoch 16/60
# 3555/3555 [==============================] - 12s 3ms/sample - loss: 0.5455 - accuracy: 0.6993 - val_loss: 1.0233 - val_accuracy: 0.4564
# Epoch 17/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.5276 - accuracy: 0.7159 - val_loss: 1.0439 - val_accuracy: 0.4444
# Epoch 18/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.5231 - accuracy: 0.7215 - val_loss: 1.0712 - val_accuracy: 0.4538
# Epoch 19/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.5118 - accuracy: 0.7207 - val_loss: 1.1280 - val_accuracy: 0.4496
# Epoch 20/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.5009 - accuracy: 0.7387 - val_loss: 1.1498 - val_accuracy: 0.4444
# Epoch 21/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4863 - accuracy: 0.7463 - val_loss: 1.1994 - val_accuracy: 0.4453
# Epoch 22/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4800 - accuracy: 0.7409 - val_loss: 1.2217 - val_accuracy: 0.4573
# Epoch 23/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4656 - accuracy: 0.7561 - val_loss: 1.3036 - val_accuracy: 0.4453
# Epoch 24/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4551 - accuracy: 0.7609 - val_loss: 1.3228 - val_accuracy: 0.4632
# Epoch 25/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4442 - accuracy: 0.7682 - val_loss: 1.3169 - val_accuracy: 0.4598
# Epoch 26/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4403 - accuracy: 0.7705 - val_loss: 1.3213 - val_accuracy: 0.4709
# Epoch 27/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4365 - accuracy: 0.7679 - val_loss: 1.4296 - val_accuracy: 0.4521
# Epoch 28/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4247 - accuracy: 0.7783 - val_loss: 1.5064 - val_accuracy: 0.4444
# Epoch 29/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4147 - accuracy: 0.7831 - val_loss: 1.5427 - val_accuracy: 0.4496
# Epoch 30/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4136 - accuracy: 0.7840 - val_loss: 1.5365 - val_accuracy: 0.4581
# Epoch 31/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.4073 - accuracy: 0.7882 - val_loss: 1.5493 - val_accuracy: 0.4436
# Epoch 32/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3973 - accuracy: 0.7989 - val_loss: 1.6362 - val_accuracy: 0.4419
# Epoch 33/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3915 - accuracy: 0.7924 - val_loss: 1.7423 - val_accuracy: 0.4359
# Epoch 34/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3868 - accuracy: 0.8070 - val_loss: 1.5989 - val_accuracy: 0.4786
# Epoch 35/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3827 - accuracy: 0.8053 - val_loss: 1.6615 - val_accuracy: 0.4564
# Epoch 36/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3760 - accuracy: 0.8084 - val_loss: 1.6758 - val_accuracy: 0.4513
# Epoch 37/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3729 - accuracy: 0.8028 - val_loss: 1.7191 - val_accuracy: 0.4650
# Epoch 38/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3742 - accuracy: 0.8090 - val_loss: 1.8468 - val_accuracy: 0.4496
# Epoch 39/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3678 - accuracy: 0.8059 - val_loss: 1.7856 - val_accuracy: 0.4701
# Epoch 40/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3640 - accuracy: 0.8115 - val_loss: 1.7764 - val_accuracy: 0.4667
# Epoch 41/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3576 - accuracy: 0.8163 - val_loss: 1.9213 - val_accuracy: 0.4615
# Epoch 42/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3560 - accuracy: 0.8183 - val_loss: 1.8343 - val_accuracy: 0.4658
# Epoch 43/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3487 - accuracy: 0.8205 - val_loss: 1.9549 - val_accuracy: 0.4675
# Epoch 44/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3488 - accuracy: 0.8219 - val_loss: 1.8766 - val_accuracy: 0.4564
# Epoch 45/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3485 - accuracy: 0.8180 - val_loss: 1.9297 - val_accuracy: 0.4675
# Epoch 46/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3392 - accuracy: 0.8284 - val_loss: 1.9817 - val_accuracy: 0.4632
# Epoch 47/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.3429 - accuracy: 0.8191 - val_loss: 2.1589 - val_accuracy: 0.4333
# Epoch 48/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.3363 - accuracy: 0.8323 - val_loss: 1.9879 - val_accuracy: 0.4573
# Epoch 49/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.3355 - accuracy: 0.8242 - val_loss: 2.0228 - val_accuracy: 0.4744
# Epoch 50/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3243 - accuracy: 0.8332 - val_loss: 2.1340 - val_accuracy: 0.4504
# Epoch 51/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3222 - accuracy: 0.8340 - val_loss: 2.1548 - val_accuracy: 0.4547
# Epoch 52/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3240 - accuracy: 0.8323 - val_loss: 2.1613 - val_accuracy: 0.4538
# Epoch 53/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3194 - accuracy: 0.8321 - val_loss: 2.2585 - val_accuracy: 0.4521
# Epoch 54/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3233 - accuracy: 0.8318 - val_loss: 2.2143 - val_accuracy: 0.4573
# Epoch 55/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3211 - accuracy: 0.8385 - val_loss: 2.2819 - val_accuracy: 0.4410
# Epoch 56/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.3260 - accuracy: 0.8343 - val_loss: 2.1860 - val_accuracy: 0.4573
# Epoch 57/60
# 3555/3555 [==============================] - 11s 3ms/sample - loss: 0.3172 - accuracy: 0.8323 - val_loss: 2.1804 - val_accuracy: 0.4650
# Epoch 58/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3192 - accuracy: 0.8363 - val_loss: 2.3110 - val_accuracy: 0.4521
# Epoch 59/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3125 - accuracy: 0.8419 - val_loss: 2.3016 - val_accuracy: 0.4573
# Epoch 60/60
# 3555/3555 [==============================] - 10s 3ms/sample - loss: 0.3065 - accuracy: 0.8363 - val_loss: 2.3891 - val_accuracy: 0.4684

# %%
plt.plot(history_conv1d.history['accuracy'])
plt.plot(history_conv1d.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  #plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)


plot_loss(history_conv1d)

# %%
X_test_indices = sentences_to_indices(test_x, word_to_index, max_len = maxLen)
Y_test_oh = keras.utils.to_categorical(test_y, 2)
loss, acc = model.evaluate(X_test_indices, Y_test_oh)

print("Test accuracy = ", acc)
# Out:
# 1190/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Test accuracy =  0.5184874
